# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import linregress

# %%
#read file 
orig_file = pd.read_csv("police_fatal_shootings.csv")
clean_file = orig_file [["date", "armed", "threat_level","age", "gender", "race", "state", 
                         "signs_of_mental_illness", "flee", "body_camera"]]
clean_file = clean_file.rename(columns={"date":"Date", 
                                        "armed":"Armed", 
                                        "threat_level":"Threat",
                                        "age":"Age", 
                                        "gender":"Gender", 
                                        "race":"Race", 
                                        "state":"State",
                                        "signs_of_mental_illness": "Sign of Mental Illness", 
                                        "flee":"Flee", 
                                        "body_camera": "Body Camera"})

clean_file.head()
# Out:
#          Date       Armed  Threat   Age Gender Race State  \
# 0  12/21/2017     unarmed   other   6.0      M    W    TX
# 1    1/6/2015     unarmed   other  34.0      F    W    IA
# 2   1/11/2016     unarmed   other  12.0      F    W    PA
# 3   9/14/2016  toy weapon   other  13.0      M    B    OH
# 4    1/7/2015         gun  attack  37.0      M    B    LA
#
#    Sign of Mental Illness         Flee  Body Camera
# 0                   False  Not fleeing        False
# 1                   False  Not fleeing         True
# 2                   False  Not fleeing        False
# 3                   False         Foot        False
# 4                   False         Foot         True

# %%
#total rows
clean_file.count()
# Out:
# Date                      4377
# Armed                     4130
# Threat                    4377
# Age                       4191
# Gender                    4372
# Race                      3856
# State                     4377
# Sign of Mental Illness    4377
# Flee                      4203
# Body Camera               4377
# dtype: int64

# %%
#clean for 2015-2018, change date column to datetime 
clean_file['Date'] = pd.to_datetime(clean_file['Date'])  
# clean_file.head()
mask = (clean_file['Date'] > '2015-01-01') & (clean_file['Date'] <= '2018-12-31')
clean_date = clean_file.loc[mask]
clean_date.head()
# Out:
#         Date       Armed  Threat   Age Gender Race State  \
# 0 2017-12-21     unarmed   other   6.0      M    W    TX
# 1 2015-01-06     unarmed   other  34.0      F    W    IA
# 2 2016-01-11     unarmed   other  12.0      F    W    PA
# 3 2016-09-14  toy weapon   other  13.0      M    B    OH
# 4 2015-01-07         gun  attack  37.0      M    B    LA
#
#    Sign of Mental Illness         Flee  Body Camera
# 0                   False  Not fleeing        False
# 1                   False  Not fleeing         True
# 2                   False  Not fleeing        False
# 3                   False         Foot        False
# 4                   False         Foot         True

# %%
#2015-2018 count
clean_date.count()
# Out:
# Date                      3934
# Armed                     3689
# Threat                    3934
# Age                       3801
# Gender                    3931
# Race                      3656
# State                     3934
# Sign of Mental Illness    3934
# Flee                      3800
# Body Camera               3934
# dtype: int64

# %%
#drop empty rows, reset index
df = clean_date.dropna(how ="any")
df.reset_index()
df.count()
# Out:
# Date                      3272
# Armed                     3272
# Threat                    3272
# Age                       3272
# Gender                    3272
# Race                      3272
# State                     3272
# Sign of Mental Illness    3272
# Flee                      3272
# Body Camera               3272
# dtype: int64

# %%
#bin by year
df["Date"].head()
cut_points = pd.to_datetime([np.datetime64('2015-01-01'), np.datetime64('2015-12-31'), np.datetime64('2016-12-31'), np.datetime64('2017-12-31'), np.datetime64('2018-12-31')])
group_names = ["2015", "2016", "2017", "2018"]
df["Year"] = pd.cut(df['Date'], cut_points, labels=group_names)
df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#         Date       Armed  Threat   Age Gender Race State  \
# 0 2017-12-21     unarmed   other   6.0      M    W    TX
# 1 2015-01-06     unarmed   other  34.0      F    W    IA
# 2 2016-01-11     unarmed   other  12.0      F    W    PA
# 3 2016-09-14  toy weapon   other  13.0      M    B    OH
# 4 2015-01-07         gun  attack  37.0      M    B    LA
#
#    Sign of Mental Illness         Flee  Body Camera  Year
# 0                   False  Not fleeing        False  2017
# 1                   False  Not fleeing         True  2015
# 2                   False  Not fleeing        False  2016
# 3                   False         Foot        False  2016
# 4                   False         Foot         True  2015

# %%
#group by year
year_group = df.groupby("Year")
year_group.head()
# Out:
#          Date       Armed        Threat   Age Gender Race State  \
# 0  2017-12-21     unarmed         other   6.0      M    W    TX
# 1  2015-01-06     unarmed         other  34.0      F    W    IA
# 2  2016-01-11     unarmed         other  12.0      F    W    PA
# 3  2016-09-14  toy weapon         other  13.0      M    B    OH
# 4  2015-01-07         gun        attack  37.0      M    B    LA
# 5  2017-11-08       knife         other  14.0      M    N    WI
# 6  2015-01-08      shovel        attack  42.0      M    W    UT
# 7  2015-06-14         gun        attack  15.0      M    W    FL
# 9  2015-10-15         gun        attack  15.0      M    H    FL
# 10 2016-04-19         gun        attack  15.0      M    B    MO
# 12 2017-04-24         gun        attack  15.0      M    B    TX
# 14 2017-08-03         gun        attack  15.0      M    B    IN
# 15 2017-09-15     crowbar         other  15.0      M    H    VA
# 17 2018-08-18         gun         other  15.0      M    H    CA
# 18 2018-01-17     unarmed         other  16.0      M    W    OH
# 19 2016-03-13     unarmed  undetermined  16.0      M    H    TX
# 27 2016-02-24       knife         other  16.0      M    W    MO
# 38 2018-02-04         gun         other  16.0      M    B    CA
# 39 2018-03-12         gun        attack  16.0      M    W    MI
# 41 2018-07-22     vehicle        attack  16.0      M    W    OK
#
#     Sign of Mental Illness         Flee  Body Camera  Year
# 0                    False  Not fleeing        False  2017
# 1                    False  Not fleeing         True  2015
# 2                    False  Not fleeing        False  2016
# 3                    False         Foot        False  2016
# 4                    False         Foot         True  2015
# 5                    False  Not fleeing        False  2017
# 6                    False  Not fleeing         True  2015
# 7                     True  Not fleeing        False  2015
# 9                    False          Car        False  2015
# 10                   False        Other        False  2016
# 12                   False  Not fleeing        False  2017
# 14                   False         Foot        False  2017
# 15                   False  Not fleeing        False  2017
# 17                   False        Other        False  2018
# 18                   False  Not fleeing        False  2018
# 19                   False          Car        False  2016
# 27                    True  Not fleeing        False  2016
# 38                   False         Foot        False  2018
# 39                    True         Foot        False  2018
# 41                   False          Car        False  2018

# %%
#create df for 2015
group_2015 = year_group.get_group('2015')
group_2015_df = pd.DataFrame(group_2015)
# group_2015_df.head()

#create df for 2016
group_2016 = year_group.get_group('2016')
group_2016_df = pd.DataFrame(group_2016)
# group_2016_df.head()

#create df for 2017
group_2017 = year_group.get_group('2017')
group_2017_df = pd.DataFrame(group_2017)
# group_2017_df.head()

#create df for 2018
group_2018 = year_group.get_group('2018')
group_2018_df = pd.DataFrame(group_2018)
# group_2018_df

# %%
#average age for each year
year_group_age_avg = year_group["Age"].mean()
avg_age_chart = year_group_age_avg.plot(kind="bar", title="Average Age of Civialian Fatally Shot by Police")
avg_age_chart.set_ylabel("Average Age of Civilian")
plt.show()

# %%
#body cam use by year
year_group_body_cam = year_group["Body Camera"].value_counts()
year_group_body_cam = pd.DataFrame({"Counts": year_group_body_cam})
year_group_body_cam
# Out:
#                   Counts
# Year Body Camera
# 2015 False           824
#      True             71
# 2016 False           686
#      True            128
# 2017 False           698
#      True             85
# 2018 False           686
#      True             94

# %% [markdown]
# # Body cam graph

# %%
#Calculate percentage with body cameras
bc_2015= (824/(824+71) * 100)
bc_2016= (686/(686+128) * 100)
bc_2017= (698/(698+85) * 100)
bc_2018= (686/(686+94) * 100)
 
print(bc_2015)
print(bc_2016)
print(bc_2017)
print(bc_2018)
#plot table of body cam use over time

years = ["2015","2016","2017","2018"]
bodycam_percent = [100 - bc_2015, 100 - bc_2016, 100 - bc_2017,100 - bc_2018]
plt.plot(years, bodycam_percent, color="green", label="Body Cam percentage")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Body Cam")
# Out:
# 92.06703910614526
# 84.27518427518427
# 89.14431673052363
# 87.94871794871794
# Text(0, 0.5, 'Body Cam')

# %% [markdown]
# # TOTAL FATAL SHOOTINGS GRAPH

# %%
#number of fatalities in each year
# year_count = year_group["Year"].count()
# count_chart = year_count.plot(title="Number of Police Fatal Shootings by Year")
# years = ["2015","2016","2017","2018"]

years = ["2015","2016","2017","2018"]
fatalshootings = (895, 814, 783, 780)
plt.plot(years, fatalshootings, color="green", label="Fatal Shootings")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Fatal Shootings")

#count_chart.set_ylabel("Number of Shootings")
plt.title("Number of Police Fatal Shootings by Year")
plt.tight_layout()
plt.show()
plt.savefig('total_fatalities_in_each_year.png')

# %%
age = year_group['Age'].value_counts()
age_table = pd.DataFrame({"Counts": age})
age_table.head()
# Out:
#            Counts
# Year Age
# 2015 27.0      34
#      31.0      34
#      28.0      33
#      35.0      33
#      29.0      32

# %%
gender = year_group['Gender'].value_counts()
gender_summary_table = pd.DataFrame({"Counts": gender})
gender_summary_table
# Out:
#              Counts
# Year Gender
# 2015 M          860
#      F           35
# 2016 M          780
#      F           34
# 2017 M          749
#      F           34
# 2018 M          740
#      F           40

# %%
gender_2015 = (860/(860+35)) * 100
gender_2016 = (780/(780+34)) * 100
gender_2017 = (749/(749+34)) * 100
gender_2018 = (740/(740+40)) * 100

years = ["2015","2016","2017","2018"]
male_percent = [gender_2015,gender_2016,gender_2017,gender_2018]
plt.plot(years, male_percent, color="green", label="Male percentage")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Gender")
# Out:
# Text(0, 0.5, 'Gender')

# %%
gender_chart = gender_summary_table.plot(kind="bar", title="Gender")
gender_chart.set_ylabel("Number of Shootings")
plt.tight_layout()
plt.show()

# %%
mental_health = year_group['Sign of Mental Illness'].value_counts()
mh_summary_table = pd.DataFrame({"Counts": mental_health})
mh_summary_table
# Out:
#                              Counts
# Year Sign of Mental Illness
# 2015 False                      656
#      True                       239
# 2016 False                      595
#      True                       219
# 2017 False                      575
#      True                       208
# 2018 False                      608
#      True                       172

# %%
mental_health_chart = mh_summary_table.plot(kind="bar", title="Mental Health Status")
mental_health_chart.set_ylabel("Number of Shootings")
plt.tight_layout()
plt.show()

# %%
race = year_group['Race'].value_counts()
race_table = pd.DataFrame({"Counts": race})
race_table
# Out:
#            Counts
# Year Race
# 2015 W        469
#      B        231
#      H        160
#      O         15
#      A         12
#      N          8
# 2016 W        424
#      B        212
#      H        141
#      A         14
#      N         14
#      O          9
# 2017 W        405
#      B        190
#      H        151
#      N         19
#      A         13
#      O          5
# 2018 W        404
#      B        201
#      H        137
#      A         20
#      N         15
#      O          3

# %%
print(type(race_table['Counts']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-7d60bf710792> in <module>
#       2 year = ["2015", "2016", "2017", "2018"]
#       3 race = race_table['Counts']
# ----> 4 (slope, intercept, _, _, _) = linregress(year, race)
#       5 fit = slope * year + intercept
#       6
#
# /anaconda3/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py in linregress(x, y)
#      87
#      88     n = len(x)
# ---> 89     xmean = np.mean(x, None)
#      90     ymean = np.mean(y, None)
#      91
#
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2918
#    2919     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2920                           out=out, **kwargs)
#    2921
#    2922
#
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      73             is_float16_result = True
#      74
# ---> 75     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      76     if isinstance(ret, mu.ndarray):
#      77         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
threat = df.groupby(['Year',"Sign of Mental Illness", "Threat"]) 
threat =threat["State"].count()
threat_df = pd.DataFrame(threat)
threat_df

# %%
body_cam = df.groupby(['Year', 'Flee', "Threat", "Body Camera"]) 
body_cam_count = body_cam["State"].count()

body_cam_table = pd.DataFrame({"Body Camera Count": body_cam_count})
body_cam_table.head()
list(body_cam_table.columns.values)
# body_cam_2015 = body_cam_table.loc[body_cam_table['Year']]
# body_cam_2015.head()

# %%
print(body_cam_table.index)

# %%
#breakdown by season using DatetimeIndex.dayofyear
df['Season'] = pd.cut(
    (df.loc[df['Date']].dt.dayofyear + 11) % 366,
    [0, 91, 183, 275, 366],
    labels=['Winter', 'Spring', 'Summer', 'Fall']
)
